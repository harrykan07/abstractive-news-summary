# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd 
import re
from keras.preprocessing.text import Tokenizer 
from nltk import download
download('stopwords')
download('wordnet')
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
from attention import AttentionLayer
from clean import clean_text
pd.set_option("display.max_colwidth", -1)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
reviews = pd.read_csv("drive/My Drive/text_summary/news_summary.csv")
print(reviews.shape)
reviews.head()
# Out:
# (98398, 2)
#                                                              headlines                                                                                                                                                                                                                                                                                                                                                                                     text
# 0  upGrad learner switches to career in ML & Al with 90% salary hike    Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.
# 1  Delhi techie wins free food from Swiggy for one year on CRED         Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
# 2  New Zealand end Rohit Sharma-led India's 12-match winning streak     New Zealand defeated India by 8 wickets in the fourth ODI at Hamilton on Thursday to win their first match of the five-match ODI series. India lost an international match under Rohit Sharma's captaincy after 12 consecutive victories dating back to March 2018. The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
# 3  Aegon life iTerm insurance plan helps customers save tax             With Aegon Life iTerm Insurance plan, customers can enjoy tax benefits on your premiums paid and save up to â¹46,800^ on taxes. The plan provides life cover up to the age of 100 years. Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
# 4  Have known Hirani for yrs, what if MeToo claims are not true: Sonam  Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman. But in this case, we need to reserve our judgment," she added. Hirani has been accused by an assistant who worked in 'Sanju'.

# %%
# Check for any nulls values
reviews.isnull().sum()

# %%
# let's inspect some reviews
for i in range(5):
    print("Review: ",i+1)
    print(reviews.headlines[i])
    print('-'*80)
    print(reviews.text[i])
    print()

# %% [markdown]
# # Lets cleaned datasets

# %%
cleaned_headlines = []
cleaned_text = []

for headlines in reviews['headlines']:
    cleaned_headlines.append(clean_text(headlines, remove_stopwords=False))
print("Headlines are complete.")

for text in reviews['text']:
    cleaned_text.append(clean_text(text))
print("Texts are complete.")
# Out:
# Headlines are complete.
# Texts are complete.

# %%
# let's inspect some clean reviews
for i in range(20):
    print("Review: ",i+1)
    print(cleaned_headlines[i])
    print('-'*80)
    print(cleaned_text[i])
    print()
# Out:
# Review:  1
# upgrad learner switches to career in ml   al with  <num>   salary hike
# --------------------------------------------------------------------------------
# saurav kant alumnus upgrad iiit b pg program machine learning artificial intelligence sr systems engineer infosys almost <num> years work experience program upgrad <num> degree career support helped transition data scientist tech mahindra <num> salary hike upgrad online power learning powered <num> lakh careers
#
# Review:  2
# delhi techie wins free food from swiggy for one year on cred
# --------------------------------------------------------------------------------
# kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending <num> cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit
#
# Review:  3
# new zealand end rohit sharma led india s  <num>  match winning streak
# --------------------------------------------------------------------------------
# new zealand defeated india <num> wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy <num> consecutive victories dating back march <num> match witnessed india getting <num> seventh lowest total odi cricket history
#
# Review:  4
# aegon life iterm insurance plan helps customers save tax
# --------------------------------------------------------------------------------
# aegon life iterm insurance plan customers enjoy tax benefits premiums paid save <num> <num> taxes plan provides life cover age <num> years also customers options insure critical illnesses disability accidental death benefit rider life cover age <num> years
#
# Review:  5
# have known hirani for yrs  what if metoo claims are not true  sonam
# --------------------------------------------------------------------------------
# speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked san
#
# Review:  18
# those on bail will go to jail  pm modi takes jibe at rahul
# --------------------------------------------------------------------------------
# jibe congress president rahul gandhi pm narendra modi wednesday said bail go jail pm modi added bail associates facing charges know convicted one day pm claimed would waged war corruption common household
#
# Review:  19
# how long can i tolerate congress leaders  potshots  k taka cm
# --------------------------------------------------------------------------------
# days threatened step post congress mlas continue crossing line karnataka chief minister hd kumaraswamy accused taking potshots asked many days tolerate stuff kumaraswamy made statements congress mla demanded siddaramaiah made cm said power ephemeral
#
# Review:  20
# odisha cm patnaik controls mining mafia  union minister
# --------------------------------------------------------------------------------
# union minister dharmendra pradhan wednesday claimed illegal mining mafia odisha operates control cm naveen patnaik state congress chief niranjan patnaik added time come people odisha put full stop activities time come us ask explanation corrupt government

# %%
# distribution of sequences
import matplotlib.pyplot as plt

text_word_count = []
headlines_word_count = []

for i in cleaned_text:
    text_word_count.append(len(i.split()))
for i in cleaned_headlines:
    headlines_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text': text_word_count, 'headlines': headlines_word_count})
length_df.hist(bins=15)
plt.show()

# %%
count = 0
for i in cleaned_text:
    if(len(i.split())<=50):
        count += 1
print(count/len(cleaned_text))
# Out:
# 0.9974592979532104

# %%
max_headlines_len=14
max_text_len=50

cleaned_text = np.array(cleaned_text)
cleaned_headlines = np.array(cleaned_headlines)

short_text=[]
short_headlines=[]

for i in range(len(cleaned_text)):
    
    if(len(cleaned_headlines[i].split())<=max_headlines_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_headlines.append(cleaned_headlines[i])

df=pd.DataFrame({'text':short_text,'headlines':short_headlines})
df['headlines'] = df['headlines'].apply(lambda x : 'sostok '+ x + ' eostok')

from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['headlines']),test_size=0.1,random_state=0,shuffle=True)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                        text                                                                             headlines
# 0  saurav kant alumnus upgrad iiit b pg program machine learning artificial intelligence sr systems engineer infosys almost <num> years work experience program upgrad <num> degree career support helped transition data scientist tech mahindra <num> salary hike upgrad online power learning powered <num> lakh careers  sostok upgrad learner switches to career in ml   al with  <num>   salary hike eostok
# 1  kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending <num> cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit                                       sostok delhi techie wins free food from swiggy for one year on cred eostok
# 2  new zealand defeated india <num> wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy <num> consecutive victories dating back march <num> match witnessed india getting <num> seventh lowest total odi cricket history                        sostok new zealand end rohit sharma led india s  <num>  match winning streak eostok
# 3  aegon life iterm insurance plan customers enjoy tax benefits premiums paid save <num> <num> taxes plan provides life cover age <num> years also customers options insure critical illnesses disability accidental death benefit rider life cover age <num> years                                                          sostok aegon life iterm insurance plan helps customers save tax eostok
# 4  speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju                                                                              sostok have known hirani for yrs  what if metoo claims are not true  sonam eostok

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

thresh=4
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# % of rare words in vocabulary: 57.576454046453776
# Total Coverage of rare words: 1.9767496529902149
# 31380

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

thresh=6
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_headlines_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_headlines_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# % of rare words in vocabulary: 64.96470513753917
# Total Coverage of rare words: 3.6936228324816986
# (87716, 87716)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 320
embedding_dim=220

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.2,recurrent_dropout=0.2)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.3,recurrent_dropout=0.1)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 220)      6903600     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 320), (N 692480      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 320), (N 820480      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 220)    2435180     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 320), (N 820480      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 320),  692480      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 320),  205120      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 640)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 11069)  7095229     concat_layer[0][0]
# ==================================================================================================
# Total params: 19,665,049
# Trainable params: 19,665,049
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Train on 87716 samples, validate on 9747 samples
# Epoch 1/50
# 87716/87716 [==============================] - 215s 2ms/sample - loss: 2.6117 - val_loss: 3.1797
# Epoch 2/50
# 87716/87716 [==============================] - 210s 2ms/sample - loss: 2.5731 - val_loss: 3.1808
# Epoch 3/50
# 87716/87716 [==============================] - 210s 2ms/sample - loss: 2.5432 - val_loss: 3.1804
# Epoch 00003: early stopping

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# 2. Save Keras Model or weights on google drive

# create on Colab directory
model.save('text_summary2.h5')    
model_file = drive.CreateFile({'title' : 'text_summary2.h5'})
model_file.SetContentFile('text_summary2.h5')
model_file.Upload()

# download to google drive
drive.CreateFile({'id': model_file.get('id')})
# Out:
# GoogleDriveFile({'id': '1scFIRAKBQnNtxK17qEGIJL-2MgseT8yP'})

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_headlines_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: addressing nation occasion num st independence day prime minister narendra modi said cannot accept violence name faith added earlier slogan bharat bharat comes context number mob lynchings taken place outrage
# Original summary: we cannot accept violence in the name of faith pm modi
# Predicted summary:  cannot stop name of violence in name pm modi
#
#
# Review: windies rounder chase ended day num second test india two runs short fourth test ton helped side post num num end day play chase along windies captain jason holder put num run stand seventh wicket umesh yadav broke partnership
# Original summary: num runs short of ton as windies score num num on day num
# Predicted summary:  ashwin scores num runs in num tests to india test series
#
#
# Review: num num num nearly num lakh indians waiting green card received num according data released us department homeland security india listed third among countries received number green cards china cuba green card allows holder live work permanently us
# Original summary: only num of indians waiting for green card got it in num
# Predicted summary:  num lakh indians cards cards to be used in num countries
#
#
# Review: saudi king salman bin abdulaziz al saud elder brother bin abdulaziz al saud headed body helps determine royal succession died wednesday num year old served defence minister two terms num num buried thursday prayers grand mosque muslim holy city mecca
# Original summary: saudi chief of council dies
# Predicted summary:  saudi arabia becomes brother s brother in law
#
#
# Review: filmmaker sanjay leela bhansali told parliamentary panel met thursday film padmavati based history poem padmavat written num sufi poet malik muhammad adding distorted history bhansali said controversy around film based rumours
# Original summary: padmavati based on s poem not on history bhansali
# Predicted summary:  i was not a padmavati but it was not a history sanjay
#
#
# Review: cab hailing startups ola uber signed shared mobility principles cities achieve goals lower emissions create cities principles include shared efficient use vehicles lanes curbs land paying fair share road use congestion pollution us based lyft also signed principles
# Original summary: ola uber sign shared for cities
# Predicted summary:  ola uber to launch its own cities in delhi
#
#
# Review: delhi chief minister arvind kejriwal sunday raised concerns reliability electronic voting machines evms mcd polls reports delhi evm malfunction people voter slips allowed vote sec kejriwal tweeted aap leader earlier alleged evm tampering recent assembly elections
# Original summary: arvind kejriwal alleges evms malfunction in mcd polls
# Predicted summary:  kejriwal s funds evm evms kejriwal
#
#
# Review: archaeologists discovered ancient city jungle guatemala region using aerial mapping technique researchers mapped num num square kilometre region found num num hidden ruins including houses buildings defence works pyramids per estimates nearly one crore people may inhabited ancient city
# Original summary: ancient city discovered under jungle in guatemala
# Predicted summary:  ancient island of num num crore discovered in africa
#
#
# Review: censor board talking jauhar scene sanjay leela bhansali padmavati said feel women organisations would take strong objection self immolation might see another form sati practice constitutionally banned country jauhar different practice sati said source censor board
# Original summary: num year old girl punches shark to survive attack
# Predicted summary:  us model accidentally shoots self while taking gun at home
#
#
# Review: swiss researchers discovered bacteria respond chemical signals also possess sense touch even absence sensory organs classical sense bacteria recognise surfaces respond mechanical stimulus within seconds said researchers mechanism also used pathogens attack host cells
# Original summary: scientists discover bacteria have a sense of touch
# Predicted summary:  scientists propose new theory on how to survive
#
#
# Review: former england captain geoffrey boycott termed india batting naive brainless arrogant batting naive irresponsible stupidity drives thoughtless boycott said india batting test series england far boycott also claimed indian batsmen learning mistakes
# Original summary: indian batsmen arrogant ex england captain
# Predicted summary:  india s ex england captain urges india to have a lot
#
#
# Review: india set achieve target universal access electricity num deadline world bank said friday india extremely well electrification num population access electricity world bank official stated comes days pm narendra modi announced indian villages access electricity
# Original summary: india to reach num power target before deadline world bank
# Predicted summary:  india to set up power power electricity by num world bank
#
#
# Review: us based scientists developed system automate production mini organs human stem cells setting experiment magnitude would take researcher day robot num minutes said scientist researchers discovered expand number blood vessel cells organoids faster drug testing
# Original summary: robots trained to grow mini organs faster than researchers
# Predicted summary:  scientists develop battery that can detect
#
#
# Review: pakistan refused return shoes kulbhushan jadhav wife security reasons delhi bjp spokesperson tajinder bagga tweeted pakistan wants slippers let us give slippers asking users order send slippers pakistan shared screenshot order placed pair slippers delivered high commissioner pakistan
# Original summary: pakistan wants slippers sent them a pair bjp spokesperson
# Predicted summary:  pak refuses to take off jadhav s face for jadhav s wife
#
#
# Review: google may reportedly shut google news service european union eu proposed link tax using news stories implemented according directive companies must pay work artists journalists use future google news depends whether eu willing alter legislation company executive said
# Original summary: google may shut its news service in eu over tax on links
# Predicted summary:  google may shut down its news eu on tax news
#
#
# Review: uidai reportedly told supreme court imposed penalty crores rupees airtel axis bank breaching terms attached aadhaar authentication however uidai explain whether penalty airtel linked decision december last year temporarily suspend e kyc licence airtel airtel payments bank
# Original summary: uidai fines airtel axis bank over aadhaar authentication
# Predicted summary:  uidai asks sc to review aadhaar data with airtel
#
#
# Review: oil gas major gail india thursday reported num year year jump net profit num num crore march quarter compared num crore quarter last fiscal company revenue rose num num num num crore quarter company shares closed num num announcement results
# Original summary: profit rises num to num num crore in march quarter
# Predicted summary:  oil price profit rises num to num num crore in june quarter
#
#
# Review: adelaide strikers num year old fast bowler ben laughlin pulled flying catch dismiss perth scorchers michael big bash league saturday michael delivery towards mid laughlin jumped towards right caught ball hands ben laughlin leading wicket taker big bash league history
# Original summary: num year old australian fielder pulls off flying catch
# Predicted summary:  num yr old cricketer takes catch while playing catch
#
#
# Review: delhi development authority dda planning plant nearly num lakh saplings across national capital ongoing monsoon season body said statement tuesday several big parks green belts bio diversity parks yamuna flood fall jurisdiction dda statement added
# Original summary: dda to plant num lakh saplings across delhi during monsoon
# Predicted summary:  delhi to get num l plant in num lakh
#
#
# Review: man deployed keep birds away flights runways delhi airport reportedly came close air india plane taxiing following pilot complained air traffic controllers however airport spokesperson said man maintained safe distance num deployed keep birds away runways delhi airport
# Original summary: bird comes near air india flight pilot complains
# Predicted summary:  man proposes flights to delhi airport air india plane mid air india
#
#
# Original summary: no vip treatment to ram rahim inmates cannot see him mla
# Predicted summary:  haryana mla denies rape charges against ram rahim
#
#
# Review: many num people killed num others wounded mosque attack took place friday egypt north sinai province general prosecutor nabil said egypt military retaliation carried air strikes saturday militants attack deadliest country carried num num militants added
# Original summary: egypt mosque terror attack death toll rises to num
# Predicted summary:  num killed num injured in mosque attack in egypt
#
#
# Review: indian rounder hardik pandya got run second test south africa failed drag bat across returning striker end pandya reached pitch half way length called indian captain virat kohli run getting run direct hit vernon philander
# Original summary: pandya gets run out after failing to drag bat across crease
# Predicted summary:  pandya gets run out for test bat gets run out
#
#
# Review: congress released list num candidates second phase polling chhattisgarh assembly elections chhattisgarh pradesh congress committee chief bhupesh baghel contest patan ex union minister charan das mahant contest total num seats go polls november num results declared december num
# Original summary: cong releases candidate list for num nd phase of c garh polls
# Predicted summary:  congress releases list of num candidates for chhattisgarh polls
#
#
# Review: known retina animals including humans contain two types rods vision dim light cones daytime vision however australia based researchers observed deep sea fish active mostly twilight combine aspects cells single efficient type dubbed rod like cones
# Original summary: rod like discovered in the eye of a deep sea fish
# Predicted summary:  human rights body found in australia s
#
#
# Review: italian space agency scientists expressed interest developing robotic technology bring asteroid beyond lunar orbit back closer reach order better study mission could also help planetary defence deflect potentially hazardous asteroid might impact earth notably nasa looking robotics development asteroid redirect mission
# Original summary: scientists propose bringing asteroid closer to earth
# Predicted summary:  scientists develop solar system to mars
#
#
# Review: nasa live streaming super blue blood moon occurring first time since num rare event features second full moon month often called blue moon coinciding lunar eclipse giving blood red tint moon also happens supermoon appearing num larger num brighter smallest full moon
# Original summary: watch live the first super blue blood moon in num years
# Predicted summary:  nasa live blue star moon mission to moon moon
#
#
# Review: former isro scientist k chandrasekhar framed spying num isro espionage case slipped coma hours supreme court verdict clearing name friday tried show tv grabs news unconscious said wife chandrasekhar falsely charged transferring confidential documents india space programme passed away sunday num
# Original summary: isro scientist framed for spying dies without hearing sc verdict
# Predicted summary:  isro scientist claims isro s ex isro scientist
#
#
# Review: russian state media criticised reportedly spreading false news us restaurant offered burger honour russian president vladimir putin birthday claimed gesture showed putin admired across world however restaurant denied claims saying never celebrated putin birthday never offered putin burger
# Original summary: russian state media slammed over fake news on putin burger
# Predicted summary:  russia slammed for selling fake news on putin
#
#
# Review: chinese bicycle sharing startup ofo expected launch services india monday reportedly made available paytm tie paytm addition stand alone mobile app lets users book bike company expected launch service pune chennai indore ahmedabad bengaluru
# Original summary: chinese bike sharing startup to launch service in india
# Predicted summary:  chinese startup to launch india s india s next month
#
#
# Review: israeli prime minister benjamin netanyahu claimed iran building military bases syria lebanon eradicate israel added iran building sites produce precision guided missiles towards end earlier netanyahu warned israel prepared intervene syria counter iran influence war
# Original summary: iran building military bases in syria lebanon israel pm
# Predicted summary:  iran will build military base in syria israel pm netanyahu
#
#
# Review: apple iphone x users reported device touchscreen turn several seconds incoming call prevents answering seeing calling apple acknowledged issue said looking reports earlier iphone x users also reported activation issues smartphones
# Original summary: users report issue of delayed incoming calls on iphone x
# Predicted summary:  iphone x x not like a x issue apple s iphone x
#
#
